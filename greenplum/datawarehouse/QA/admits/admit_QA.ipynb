# %% [markdown]
# # Data Warehouse Admission Acute IP QA

# %%
import pandas as pd
import psycopg2
import sys
sys.path.append('H:/')
from uth_helpers.db_utils import get_dsn

# %%
connection = psycopg2.connect(get_dsn()+' keepalives=1 keepalives_idle=30 keepalives_interval=10')

# %% [markdown]
# ## Checking Counts of Admit table and Admit Claims Table

# %%
query = '''
select data_source, count(*) admit_row_count, count(distinct admit_id) admit_count, count(distinct uth_member_id) pat_count
from dev.gm_dw_ip_admit
group by 1;
'''

admit_df = pd.read_sql(query, con=connection)
admit_df
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   data_source  admit_row_count  admit_count  pat_count
# 0        mhtw            16758        16758      13112
# 1        mcpp           352067       352067     270227
# 2        trum          1750303      1750303     946315
# 3        mcrt          3742109      3742109    1487393
# 4        mcrn          2646701      2646701    1071737
# 5        mdcd          6242921      6242921    3651344
# 6        truc          8527365      8527365    5891961
# 7        optd         10839102     10839102    6176069
# 8        optz         10844126     10844126    6187088

# %%
query = '''
select data_source, count(*) claim_row_count, count(distinct admit_id) admit_count, count(distinct uth_member_id) pat_count
from dev.gm_dw_ip_admit_claim
group by 1;
'''

admit_claim_df = pd.read_sql(query, con=connection)
admit_claim_df
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   data_source  claim_row_count  admit_count  pat_count
# 0        mhtw           122579        16758      13112
# 1        mcpp          1630844       352067     270227
# 2        trum         26176725      1750303     946315
# 3        mcrt         59116944      3742109    1487393
# 4        mcrn         39565398      2646701    1071737
# 5        mdcd         57031058      6242921    3651344
# 6        truc         83088932      8527365    5891961
# 7        optd        147252249     10839100    6176067
# 8        optz        148455719     10844124    6187086

# %%
comp_df = pd.merge(left=admit_df, right=admit_claim_df, on='data_source')
comp_df
# Out:
#   data_source  admit_row_count  admit_count_x  pat_count_x  claim_row_count  \
# 0        mhtw            16758          16758        13112           122579
# 1        mcpp           352067         352067       270227          1630844
# 2        trum          1750303        1750303       946315         26176725
# 3        mcrt          3742109        3742109      1487393         59116944
# 4        mcrn          2646701        2646701      1071737         39565398
# 5        mdcd          6242921        6242921      3651344         57031058
# 6        truc          8527365        8527365      5891961         83088932
# 7        optd         10839102       10839102      6176069        147252249
# 8        optz         10844126       10844126      6187088        148455719
#
#    admit_count_y  pat_count_y
# 0          16758        13112
# 1         352067       270227
# 2        1750303       946315
# 3        3742109      1487393
# 4        2646701      1071737
# 5        6242921      3651344
# 6        8527365      5891961
# 7       10839100      6176067
# 8       10844124      6187086

# %% [markdown]
# Ideally, the number of unique admits should be the same in both tables. If it doesn't then we need to figure out if there is a significant difference between the two tables. This difference can happen due to the dates that are on the claims in both the detail and header levels.

# %%
comp_df['admit_count_same'] = comp_df['admit_count_x'] == comp_df['admit_count_y']
comp_df['pat_count_same'] = comp_df['pat_count_x'] == comp_df['pat_count_y']
comp_df
# Out:
#   data_source  admit_row_count  admit_count_x  pat_count_x  claim_row_count  \
# 0        mhtw            16758          16758        13112           122579
# 1        mcpp           352067         352067       270227          1630844
# 2        trum          1750303        1750303       946315         26176725
# 3        mcrt          3742109        3742109      1487393         59116944
# 4        mcrn          2646701        2646701      1071737         39565398
# 5        mdcd          6242921        6242921      3651344         57031058
# 6        truc          8527365        8527365      5891961         83088932
# 7        optd         10839102       10839102      6176069        147252249
# 8        optz         10844126       10844126      6187088        148455719
#
#    admit_count_y  pat_count_y  admit_count_same  pat_count_same
# 0          16758        13112              True            True
# 1         352067       270227              True            True
# 2        1750303       946315              True            True
# 3        3742109      1487393              True            True
# 4        2646701      1071737              True            True
# 5        6242921      3651344              True            True
# 6        8527365      5891961              True            True
# 7       10839100      6176067             False           False
# 8       10844124      6187086             False           False

# %% [markdown]
# ## Checking if there are any admissions episodes that overlap

# %% [markdown]
# Again, there shouldn't be any admissions that overlap with each other, but if there is, we need to investigate.

# %%
query ='''
select a.data_source, count(*) --a.admit_date as a_admit_dt, b.admit_date as b_admit_dt, b.discharge_date as b_discharge_date
from dev.gm_dw_ip_admit a 
inner join dev.gm_dw_ip_admit b
on a.data_source = b.data_source
and a.uth_member_id = b.uth_member_id
and a.admit_date between b.admit_date+1 and b.discharge_date
group by 1;
'''

pd.read_sql(query, con=connection)
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Empty DataFrame
# Columns: [data_source, count]
# Index: []

# %%
query ='''
select a.data_source, a.admit_date as a_admit_dt, a.discharge_date as a_discharge_date, 
        b.admit_date as b_admit_dt, b.discharge_date as b_discharge_date,
        a.admit_id, b.admit_id
from dev.gm_dw_ip_admit a 
inner join dev.gm_dw_ip_admit b
on a.data_source = b.data_source
and a.uth_member_id = b.uth_member_id
and a.admit_date between b.admit_date+1 and b.discharge_date;
'''

pd.read_sql(query, con=connection)
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Empty DataFrame
# Columns: [data_source, a_admit_dt, a_discharge_date, b_admit_dt, b_discharge_date, admit_id, admit_id]
# Index: []

# %% [markdown]
# ## Checking Admission and Discharge Dates

# %% [markdown]
# Here we check the dates for admission and discharge to see if the dates are outside the initial range of years we generated the admit tables for.

# %%
query = '''
select data_source,
	sum(case when extract(year from admit_date) not between 2011 and 2023 then 1 else 0 end) as admit_oor,
	sum(case when extract(year from discharge_date) not between 2011 and 2023 then 1 else 0 end) as discharge_oor,
	sum(case when (discharge_date - admit_date) < 0 then 1 else 0 end ) as discharge_before_admit,
	count(*),
	sum(case when extract(year from admit_date) not between 2011 and 2023 then 1 else 0 end) * 1.0 / count(*) as admit_oor_pct,
	sum(case when extract(year from discharge_date) not between 2011 and 2023 then 1 else 0 end) * 1.0 / count(*) as discharge_oor_pct,
	sum(case when (discharge_date - admit_date) < 0 then 1 else 0 end ) * 1.0 / count(*) as discharge_before_admit_pct
from dev.gm_dw_ip_admit
group by data_source;
'''

pd.read_sql(query, con=connection)
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   data_source  admit_oor  discharge_oor  discharge_before_admit     count  \
# 0        truc          0              0                       0   8527365
# 1        mhtw          0              0                       0     16758
# 2        mcrn         12              0                       0   2646701
# 3        trum          0              0                       0   1750303
# 4        mcpp          0              0                       0    352067
# 5        mcrt         10              0                       0   3742109
# 6        optd          0              1                       0  10839102
# 7        mdcd          0              2                       0   6242921
# 8        optz          0              1                       0  10844126
#
#    admit_oor_pct  discharge_oor_pct  discharge_before_admit_pct
# 0       0.000000       0.000000e+00                         0.0
# 1       0.000000       0.000000e+00                         0.0
# 2       0.000005       0.000000e+00                         0.0
# 3       0.000000       0.000000e+00                         0.0
# 4       0.000000       0.000000e+00                         0.0
# 5       0.000003       0.000000e+00                         0.0
# 6       0.000000       9.225857e-08                         0.0
# 7       0.000000       3.203629e-07                         0.0
# 8       0.000000       9.221582e-08                         0.0

# %%
query = '''
select *
from dev.gm_dw_ip_admit
where extract(year from admit_date) not between 2011 and 2023;'''

pd.read_sql(query, con=connection)
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    data_source  uth_member_id  enc_id  admit_date discharge_date  \
# 0         mcrt      361005906       0  2010-10-03     2016-10-11
# 1         mcrn      533430040       0  2007-02-01     2016-08-31
# 2         mcrt      530439252       0  2010-03-27     2015-04-03
# 3         mcrn      532962777       0  2007-06-20     2017-07-09
# 4         mcrn      531994797       0  2008-08-08     2015-08-17
# 5         mcrt      358459887       0  2007-06-20     2017-07-09
# 6         mcrt      361182011       0  2007-08-23     2017-09-04
# 7         mcrt      530472500       0  2010-07-28     2015-10-09
# 8         mcrn      533467104       0  2010-02-09     2020-02-10
# 9         mcrn      533336581       0  2009-07-10     2019-07-11
# 10        mcrn      530857305       0  2007-12-08     2017-12-22
# 11        mcrt      359372597       0  2010-05-18     2019-05-22
# 12        mcrt      361949627       0  2010-05-08     2019-05-29
# 13        mcrt      359207208       0  2009-08-28     2019-06-29
# 14        mcrn      532213726       0  2008-03-01     2018-03-11
# 15        mcrt      362017706       0  2010-06-13     2017-06-13
# 16        mcrn      532830773       0  2009-01-29     2016-12-13
# 17        mcrn      532158827       0  2010-06-08     2019-09-04
# 18        mcrt      360681572       0  2010-01-09     2020-01-12
# 19        mcrn      532021750       0  2010-09-07     2019-09-12
# 20        mcrn      531104889       0  2010-05-27     2020-07-04
# 21        mcrn      532407732       0  2010-05-03     2019-05-31
#
#    enc_discharge_status            admit_id  total_charge_amount  \
# 0                    62  361005906-000-2010           4418784.50
# 1                    30  533430040-000-2007           2812899.83
# 2                    02  530439252-000-2010           1654395.29
# 3                    06  532962777-000-2007            591049.04
# 4                    51  531994797-000-2008            393800.94
# 5                    06  358459887-000-2007            591049.04
# 6                    06  361182011-000-2007           1000376.20
# 7                    06  530472500-000-2010            381247.84
# 8                    20  533467104-000-2010            938035.38
# 9                    03  533336581-000-2009            964866.61
# 10                   03  530857305-000-2007            378318.89
# 11                   05  359372597-000-2010            487285.44
# 12                   03  361949627-000-2010            542931.37
# 13                   51  359207208-000-2009            438736.98
# 14                   03  532213726-000-2008            490457.57
# 15                   01  362017706-000-2010            133472.67
# 16                   01  532830773-000-2009           4564107.80
# 17                   30  532158827-000-2010           9420545.48
# 18                   20  360681572-000-2010           1786696.98
# 19                   01  532021750-000-2010             45985.77
# 20                   01  531104889-000-2010           1491568.36
# 21                   30  532407732-000-2010           8293589.22
#
#     total_allowed_amount  total_paid_amount  missing_terminal_status  \
# 0              396999.48          342969.87                    False
# 1                2050.09            1329.49                    False
# 2              234694.72          199892.79                    False
# 3               85205.92           75782.86                    False
# 4              165881.70          140049.13                    False
# 5               85205.92           75782.86                    False
# 6              130354.21          113916.12                    False
# 7               91372.83           81296.83                    False
# 8              195186.33          168925.51                    False
# 9              239733.61          224240.23                    False
# 10             121491.32          108564.19                    False
# 11             142290.00          127888.03                    False
# 12             309540.05          283101.92                    False
# 13             128996.43          119353.97                    False
# 14              84345.72           71213.73                    False
# 15              24293.52           19564.54                    False
# 16              75071.03           54208.03                    False
# 17              34267.08           31180.81                    False
# 18             160397.82          141817.07                    False
# 19              17332.85           12313.27                    False
# 20             368550.73          341503.78                    False
# 21              94865.49           87001.93                    False
#
#     missing_terminal_status_117 paid_status    member_id_src  \
# 0                          True        None  ggggggguawffayy
# 1                         False        None  gggggggAgggyfBA
# 2                         False        None  gggggggaynjywnA
# 3                         False        None  gggggggwfAaanya
# 4                         False        None  gggggggBuuyBnwa
# 5                         False        None  gggggggwfAaanya
# 6                          True        None  gggggggngfnBgyj
# 7                         False        None  gggggggBgAgyBju
# 8                         False        None  gggggggjwuAauAy
# 9                          True        None  gggggggfwfBBgAB
# 10                         True        None  ggggggjngBgwuuj
# 11                         True        None  ggggggjnjBgwjyf
# 12                        False        None  gggggggngaBguaa
# 13                         True        None  gggggggjyyujfgA
# 14                         True        None  gggggggfafyBBff
# 15                        False        None  gggggggwwyfygfa
# 16                        False        None  gggggggfyugfaag
# 17                        False        None  ggggggggBnwygjg
# 18                        False        None  ggggggjAAyjAwaa
# 19                        False        None  ggggggjfnnawjfA
# 20                         True        None  ggggggjAagaugff
# 21                        False        None  ggggggggBjjAuAy
#
#              insert_ts
# 0  2023-09-18 14:25:01
# 1  2023-09-18 14:44:10
# 2  2023-09-18 14:29:45
# 3  2023-09-18 14:43:18
# 4  2023-09-18 14:40:42
# 5  2023-09-18 14:13:55
# 6  2023-09-18 14:25:01
# 7  2023-09-18 14:29:45
# 8  2023-09-18 14:44:10
# 9  2023-09-18 14:44:10
# 10 2023-09-18 14:38:07
# 11 2023-09-18 14:20:32
# 12 2023-09-18 14:27:34
# 13 2023-09-18 14:19:07
# 14 2023-09-18 14:41:34
# 15 2023-09-18 14:27:34
# 16 2023-09-18 14:42:25
# 17 2023-09-18 14:41:34
# 18 2023-09-18 14:23:26
# 19 2023-09-18 14:40:42
# 20 2023-09-18 14:38:59
# 21 2023-09-18 14:41:34

# %%
query = '''
select *
from dev.gm_dw_ip_admit
where extract(year from discharge_date) not between 2011 and 2023;'''

pd.read_sql(query, con=connection)
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   data_source  uth_member_id  enc_id  admit_date discharge_date  \
# 0        optz     1056840675       0  2019-10-18     2029-10-22
# 1        optd     1125923772       0  2019-10-18     2029-10-22
# 2        mdcd      672678906       0  2021-10-10     2024-10-22
# 3        mdcd     1190592142       0  2021-08-01     2027-08-02
#
#   enc_discharge_status             admit_id  total_charge_amount  \
# 0                   00  1056840675-000-2019             50591.03
# 1                   00  1125923772-000-2019             51754.62
# 2                   01   672678906-000-2021            467356.00
# 3                   01  1190592142-000-2021             33416.58
#
#    total_allowed_amount  total_paid_amount  missing_terminal_status  \
# 0              50591.00                NaN                    False
# 1              51754.59                NaN                    False
# 2                 60.00              58.80                    False
# 3               2026.26             846.04                    False
#
#    missing_terminal_status_117 paid_status    member_id_src  \
# 0                        False        None  560499258253711
# 1                        False        None      33170178655
# 2                        False        None        512249890
# 3                        False        None        749709742
#
#             insert_ts
# 0 2023-09-18 17:00:27
# 1 2023-09-18 18:03:12
# 2 2023-09-18 16:06:54
# 3 2023-09-18 16:33:52

# %% [markdown]
# ## Checking Bill Types at the beginning and end of an admit episode

# %% [markdown]
# In step 2, we added a column to determine whether during an admission episode had terminal bill codes (111, 114, 117) which indicate the start/end of an inpatient stay.

# %%
query = '''
select data_source, missing_terminal_status, count(*), 100.* count(*) / sum(count(*)) over (partition by data_source)
from dev.gm_dw_ip_admit
group by 1,2
order by 1,2;
'''

pd.read_sql(query, con=connection)
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    data_source  missing_terminal_status     count   ?column?
# 0         mcpp                    False    352022  99.987218
# 1         mcpp                     True        45   0.012782
# 2         mcrn                    False   2643950  99.896059
# 3         mcrn                     True      2751   0.103941
# 4         mcrt                    False   3739563  99.931963
# 5         mcrt                     True      2546   0.068037
# 6         mdcd                    False   6127514  98.151394
# 7         mdcd                     True    115407   1.848606
# 8         mhtw                    False     16718  99.761308
# 9         mhtw                     True        40   0.238692
# 10        optd                    False  10639006  98.153943
# 11        optd                     True    200096   1.846057
# 12        optz                    False  10663386  98.333291
# 13        optz                     True    180740   1.666709
# 14        truc                    False   8233285  96.551338
# 15        truc                     True    294080   3.448662
# 16        trum                    False   1747692  99.850826
# 17        trum                     True      2611   0.149174

# %%
query = '''
select data_source, missing_terminal_status_117, count(*), 100.* count(*) / sum(count(*)) over (partition by data_source)
from dev.gm_dw_ip_admit
group by 1,2
order by 1,2;
'''

pd.read_sql(query, con=connection)
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    data_source  missing_terminal_status_117     count   ?column?
# 0         mcpp                        False    349545  99.283659
# 1         mcpp                         True      2522   0.716341
# 2         mcrn                        False   2618302  98.927004
# 3         mcrn                         True     28399   1.072996
# 4         mcrt                        False   3678852  98.309590
# 5         mcrt                         True     63257   1.690410
# 6         mdcd                        False   6111476  97.894495
# 7         mdcd                         True    131445   2.105505
# 8         mhtw                        False     16751  99.958229
# 9         mhtw                         True         7   0.041771
# 10        optd                        False  10293096  94.962627
# 11        optd                         True    546006   5.037373
# 12        optz                        False  10280544  94.802882
# 13        optz                         True    563582   5.197118
# 14        truc                        False   8280816  97.108732
# 15        truc                         True    246549   2.891268
# 16        trum                        False   1659604  94.818097
# 17        trum                         True     90699   5.181903

# %% [markdown]
# ## Other

# %% [markdown]
# Double checking that member_id_src and claim_id_src are filled in the tables.

# %%
query = '''
select data_source, count(*)
from dev.gm_dw_ip_admit
where member_id_src is null or member_id_src = ''
group by 1'''

pd.read_sql(query, con=connection)
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Empty DataFrame
# Columns: [data_source, count]
# Index: []

# %%
query = '''
select data_source, count(*)
from dev.gm_dw_ip_admit_claim
where member_id_src is null or member_id_src = ''
or claim_id_src is null or claim_id_src = ''
group by 1'''

pd.read_sql(query, con=connection)
# Out:
# C:\Users\iperez9\.conda\envs\psycog_env\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Empty DataFrame
# Columns: [data_source, count]
# Index: []
